# %%
from differenttasks import multiplefunctions

# %%
multiplefunctions.divisablebyfive()
# Out:
# enter the number to check: 56
# number is  not divisable by 5

# %%
multiplefunctions.agecategory()
# Out:
# Enter the age: 46
# ciizen

# %%
multiplefunctions.triangle()
# Out:
# Height: 56
# Breath: 41
# Area formula=(Height*Breath)/2
# Area of Triangle: 1148.0
# Height1: 5
# Height2: 9
# Breath1: 11
# Perimeter formula= Height1+Height2+Breath
# Perimeter of Triangle: 25

# %%
multiplefunctions.subfields()
# Out:
# Subfields in AI are:
# Mechine learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Naural Language Processing
