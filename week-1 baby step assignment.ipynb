# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Add=int(input("Num1"))+int(input("Num2"))
print("Add=", Add)
# Out:
# Num1 1
# Num2 3
# Add= 4

# %%
bmi=int(input("enter the BMI Intex"))
if(bmi<18.5):
    print("Under weight")
elif(bmi<=25):
    print("Normal weight")
elif(bmi<=30):
    print("Over weight")
else:
    print("very Over weight")
# Out:
# enter the BMI Intex 14
# Under weight
