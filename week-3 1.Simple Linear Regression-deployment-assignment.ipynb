# %%
# pickling is a built-in module used for serializing and deserializing Python objects
import pickle

# %%
#loaded_model is to read binary for predictions
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))
#result is a variable which stores the output value for the given data 15
result=loaded_model.predict([[15]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#checking the output obtained for particular input
result
# Out:
# array([[167181.3106341]])

# %%
#result is a variable which stores the output value for the given data 0
result=loaded_model.predict([[0]])
#checking the output obtained for particular input
result
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])
