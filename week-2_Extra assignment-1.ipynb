# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=str(input("Enter your institute name?"))
# Out:
# Enter your institute name? HOPE AI

# %%
name=str(input("Enter your name:"))
age=int(input("Enter your age:"))
schoolname=str(input("Enter your school name:"))
name=str(input("Enter your degree:"))
# Out:
# Enter your name: manjula
# Enter your age: 32
# Enter your school name: rasama school
# Enter your degree: M.E VLSI DESIGN

# %%
add=int(input("a="))+int(input("b="))
print("add=", add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
sub=int(input("a="))-int(input("b="))
print("Sub=", sub)
# Out:
# a= 54
# b= 23
# Sub= 31

# %%
mul=int(input("a="))*int(input("b="))
print("Mul=", mul)
# Out:
# a= 43
# b= 23
# Mul= 989

# %%
div=int(input("a="))/int(input("b="))
print("Float Div=", div)
# Out:
# a= 56
# b= 13
# Float Div= 4.3076923076923075

# %%
div=int(input("a="))//int(input("b="))
print("Floor Div=", div)
# Out:
# a= 56
# b= 11
# Floor Div= 5

# %%
modulo=int(input("a="))%int(input("b="))
print("Modulo=", modulo)
# Out:
# a= 94
# b= 23
# Modulo= 2

# %%
power=int(input("a="))**int(input("b="))
print("Power=", power)
# Out:
# a= 3
# b= 5
# Power= 243
